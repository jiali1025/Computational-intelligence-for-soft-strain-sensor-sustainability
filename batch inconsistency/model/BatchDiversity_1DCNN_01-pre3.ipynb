# %%
import torch.nn as nn
import torch
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
import csv
import os
torch.cuda.empty_cache()

class StrainDataset(Dataset):
    def __init__(self, path, mode='train', sequence_length=500, transforms=None):
        self.path = path
        self.mode = mode
        self.transforms = transforms
        self.seq_len = sequence_length
        with open(path, 'r') as fp:
            data = list(csv.reader(fp))
            data = np.array(data)
            features = data[1::30, 2:5]  
            target = data[1::30, 5:6]
            all_time = data[1::30, 2:3]  
            resistance_f = data[1::30, 2:3]
            cycle_num = data[1::30, 3:4]

            y = target.astype(float)
            self.y = torch.tensor(y)
            X = features.astype(float)
            self.X = torch.tensor(X)
            time = all_time.astype(float)
            self.time = torch.tensor(time)
            resis_f = resistance_f.astype(float)
            self.resis_f = torch.tensor(resis_f)
            cyc_n = cycle_num.astype(float)
            self.cyc_n = torch.tensor(cyc_n)

            self.X[:, :] = \
                (self.X[:, :] - self.X[:, :].mean(dim=0, keepdim=True)) \
                / self.X[:, :].std(dim=0, keepdim=True)
        print('Finished reading the {} set of Strain Dataset ({} samples found)'.format(mode, len(self.X)))

    def __len__(self):
        return len(self.X)

    def __getitem__(self, index):
        if index >= self.seq_len - 1:
            i_start = index - self.seq_len + 1
            x = self.X[i_start:(index + 1), :]
            time = self.time[i_start:(index + 1), :]
            resist = self.resis_f[i_start:(index + 1), :]
            cycle = self.cyc_n[i_start:(index + 1), :]
        else:
            padding = self.X[0].repeat(self.seq_len - index - 1, 1)
            x = self.X[0:(index + 1), :]
            x = torch.cat((padding, x), 0)
            padding_time = self.time[0].repeat(self.seq_len - index - 1, 1)
            time = self.time[0:(index + 1), :]
            time = torch.cat((padding_time, time), 0)
            padding_resist = self.resis_f[0].repeat(self.seq_len - index - 1, 1)
            resist = self.resis_f[0:(index + 1), :]
            resist = torch.cat((padding_resist, resist), 0)
            padding_cycle = self.cyc_n[0].repeat(self.seq_len - index - 1, 1)
            cycle = self.cyc_n[0:(index + 1), :]
            cycle = torch.cat((padding_cycle, cycle), 0)
        return x, self.y[index], time, resist, cycle

def get_device():
    return 'cuda'if torch.cuda.is_available() else 'cpu'
device = get_device()

class CNNnetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1d = nn.Conv1d(3, 256, kernel_size= 5)
        self.relu = nn.ReLU(inplace=True)
        self.pool1d = nn.MaxPool1d(kernel_size=30 - 5 + 1)
        self.fc1 = nn.Linear(256, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):  
        x = x.permute(0, 2, 1)  
        x = self.conv1d(x) 
        x = self.relu(x)
        x = self.pool1d(x) 
        fc_inp = x.view(-1, x.size(1))
        x = self.fc1(fc_inp)  
        x = self.relu(x)
        x = self.fc2(x)  
        return x

model = CNNnetwork()
loss_funtion = nn.MSELoss()
# training
def train(model_tr_data,dv_set,model,config,device):
    '''GRU training'''
    n_epochs = config['n_epochs']  
    # Setup optimizer
    optimizer = getattr(torch.optim, config['optimizer'])(
        model.parameters(), **config['optim_hparas'])
    min_mse = 1000
    loss_record = {'train': [], 'dev': []}   
    early_stop_cnt = 0
    epoch = 0
    num_batche_tr = len(model_tr_data)
    print(num_batche_tr)
    while epoch < n_epochs:
        print(epoch)
        allbat_mse_loss = 0
        model.train()  
        for x, y, t, r, c in model_tr_data:  
            model.zero_grad()  
            x = x.float().to(device)
            pred = model(x)   
            y = y.float().to(device)
            mse_loss = loss_funtion(pred, y)   
            allbat_mse_loss += mse_loss
            mse_loss.backward()  
            optimizer.step()   
        evepoch_mse_loss = allbat_mse_loss / num_batche_tr
        print(evepoch_mse_loss)
        loss_record['train'].append(evepoch_mse_loss.detach().cpu().item())
        dev_mse = dev(dv_set, model, device)
        if dev_mse < min_mse:    
            min_mse = dev_mse
            print('Saving model (epoch = {},loss = {:.4f}'.format((epoch + 1), (min_mse)))
            torch.save(model.state_dict(), config ['save_path'])     
            early_stop_cnt = 0
        else:
            early_stop_cnt = early_stop_cnt + 1
        epoch = epoch + 1
        loss_record['dev'].append(dev_mse)
        if early_stop_cnt > config['early_stop']:
            break
    print('Finished training after {} epochs'.format(epoch))
    return min_mse, loss_record   

def dev(dv_set, model, device):
    model.eval()  
    total_loss = 0
    num_batches = len(dv_set)
    for i, y, t, r, c in dv_set:
        x = i.float().to(device)
        with torch.no_grad():
            pred = model(x)
            y = y.float().to(device)
            mse_loss = loss_funtion(pred, y)
        total_loss += mse_loss.detach().cpu().item()
    avg_loss = total_loss / num_batches  
    return avg_loss

def test(tt_set, model, device):
    model.eval()
    preds = []
    test_loss = 0.0
    num_batches = len(tt_set)
    for x, y, t, r, c in tt_set: 
        x = x.float().to(device)
        y = y.float().to(device)
        with torch.no_grad():
            pred = model(x)
            batch_loss = loss_funtion(pred, y)
            preds.append(pred.detach().cpu()) 
        test_loss += batch_loss.detach().cpu().item()
    avg_loss_test = test_loss / num_batches
    preds = torch.cat(preds, dim=0).numpy()
    print('Finished testing predictions!')
    return preds, avg_loss_test    

def plot_learning_curve(loss_record, title=''):
    total_epochs = len(loss_record['train'])
    x_1 = range(total_epochs)
    x_2 = x_1[::len(loss_record['train']) // len(loss_record['dev'])]  
    figure(figsize=(6, 4))
    plt.plot(x_1, loss_record['train'], c='tab:red', label= 'train')
    plt.plot(x_2, loss_record['dev'], c='tab:cyan', label='dev')
    plt.ylim(0.0, 100.0)
    plt.xlabel('Training epochs')
    plt.ylabel('MSE loss')
    plt.title('Learning curve of {}'.format(title))
    plt.legend()    
    plt.show()
    
def plot_pred(dv_x,model,device,lim_x=60,lim_y=4000.,preds=None,targets=None, title=''):       

    if preds is None or targets is None:
        model.eval()
        preds, targets = [], []
        resist = []
        for i, y, t, r, c in dv_x:
            x = i.float().to(device)
            y = y.float().to(device)
            t = t.float().to(device)
            r = r.float().to(device)
            with torch.no_grad():
                pred = model(x)
                resist.append(r[:, -1, :].detach().cpu())
                preds.append(pred.detach().cpu())
                targets.append(y.detach().cpu())
        preds = torch.cat(preds, dim=0).numpy()
        targets = torch.cat(targets, dim=0).numpy()
        resist_values = torch.cat(resist, dim=0).numpy()


    fig, ax1 = plt.subplots()
    ax1.set_xlabel('resistance')
    ax1.set_ylabel('ground truth value', color='red')

    ax1.scatter(resist_values, targets, color='red')
    ax1.tick_params(axis='y', labelcolor='red')
    # adding twin Axes
    ax2 = ax1.twinx()
    ax2.set_ylabel('predicted value', color='blue')
    ax2.scatter(resist_values, preds, color='blue')
    ax2.tick_params(axis='y', labelcolor='blue')
    plt.title('Ground Truth v.s. Prediction of {}'.format(title))
    plt.show()

def plot_pred_time(dv_x, model, device, preds=None, targets=None, title=''):

    if preds is None or targets is None:
        model.eval()
        preds, targets = [], []
        all_time = []
        for i, y, t, r, c in dv_x:
            x = i.float().to(device)
            y = y.float().to(device)
            t = t.float().to(device)

            with torch.no_grad():
                pred = model(x)
                all_time.append(t[:, -1, :].detach().cpu())
                preds.append(pred.detach().cpu())
                targets.append(y.detach().cpu())
        preds = torch.cat(preds, dim=0).numpy()
        targets = torch.cat(targets, dim=0).numpy()
        time_values = torch.cat(all_time, dim=0).numpy()

    # create plot
    fig, ax1 = plt.subplots()
    ax1.set_xlabel('all time')
    ax1.set_ylabel('ground truth value', color='red')

    ax1.scatter(time_values, targets, color='red')
    ax1.tick_params(axis='y', labelcolor='red')

    ax2 = ax1.twinx()
    ax2.set_ylabel('predicted value', color='blue')
    ax2.scatter(time_values, preds, color='blue')
    ax2.tick_params(axis='y', labelcolor='blue')
    plt.title('Ground Truth v.s. Prediction of {}'.format(title))
    plt.show()

    
# setup hyper-parameters
os.makedirs('BatchDiversity_1DCNN_models/BatchDiversity_1DCNN_01_1589Preds3', exist_ok=True)  
config = {
        'n_epochs': 100,  
        'batch_size': 36,   
        'optimizer': 'Adam',   
        'optim_hparas': {    
        'lr': 0.0001,    
        },
        'early_stop': 100,  
        'save_path': 'BatchDiversity_1DCNN_models/BatchDiversity_1DCNN_01_1589Preds3.pth'  
}    
    
dataset = StrainDataset('./Training_batchdiversity_1589.csv', 'train', 30, transforms=None) 
dataset_for_test_01 = StrainDataset('./Testing_batchdiversity_10.csv', 'test', 30, transforms=None)
def train_dev_data(x_set):
    X = []
    deX = []
    for i in range(len(x_set)):
        if i % 10 != 0:
            x_data = x_set[i]
            X.append(x_data)
        else:
            devX = x_set[i]
            deX.append(devX)
    return X, deX   
training_data ,valid_data = train_dev_data(dataset)
batch_size = 36
torch.manual_seed(99)
model_tr_data = DataLoader(training_data, batch_size=batch_size, shuffle=True, drop_last=True)
model_dev_data = DataLoader(valid_data, batch_size=batch_size, shuffle=True, drop_last=True)
model_tt_dataX01 = DataLoader(dataset_for_test_01, batch_size=batch_size, shuffle=False, drop_last=True)

model = model.to(device)
model_loss, model_loss_record = train(model_tr_data, model_dev_data,model, config, device)
total_params = sum(p.numel() for p in model.parameters())
print('total params = ', total_params)
print(model_loss)
len_tr = model_loss_record['train']
print(len_tr)
len_dev = model_loss_record['dev']
print(len(len_dev))
plot_learning_curve(model_loss_record, title='1dCNN model')

del model
model = CNNnetwork()
model = model.to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')   
model.load_state_dict(ckpt)

def save_pred(preds, file):
    print('Saving results to {}'.format(file))
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['id', 'strain'])
        for i, p in enumerate(preds):     
            writer.writerow([i, p])

preds01, test_loss01 = test(model_tt_dataX01, model, device) 
print(preds01)
print(test_loss01)
save_pred(preds01, 'BatchDiversity_1DCNN_01_1589Preds10.csv') 
print('ALL Done!')
# Out:
# Finished reading the train set of Strain Dataset (325878 samples found)
# Finished reading the test set of Strain Dataset (81620 samples found)
# 8146
# 0
# tensor(221.2050, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 1,loss = 209.2630
# 1
# tensor(210.0338, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 2,loss = 208.9835
# 2
# tensor(209.7170, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 3,loss = 208.5410
# 3
# tensor(209.4970, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 4,loss = 208.5315
# 4
# tensor(209.3463, device='cuda:0', grad_fn=<DivBackward0>)
# 5
# tensor(209.1996, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 6,loss = 208.2377
# 6
# tensor(209.1348, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 7,loss = 208.0920
# 7
# tensor(209.0624, device='cuda:0', grad_fn=<DivBackward0>)
# 8
# tensor(209.0291, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 9,loss = 208.0764
# 9
# tensor(208.9921, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 10,loss = 208.0307
# 10
# tensor(208.9376, device='cuda:0', grad_fn=<DivBackward0>)
# 11
# tensor(208.9066, device='cuda:0', grad_fn=<DivBackward0>)
# 12
# tensor(208.8847, device='cuda:0', grad_fn=<DivBackward0>)
# 13
# tensor(208.8677, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 14,loss = 207.8120
# 14
# tensor(208.8515, device='cuda:0', grad_fn=<DivBackward0>)
# 15
# tensor(208.8401, device='cuda:0', grad_fn=<DivBackward0>)
# 16
# tensor(208.8430, device='cuda:0', grad_fn=<DivBackward0>)
# 17
# tensor(208.8056, device='cuda:0', grad_fn=<DivBackward0>)
# 18
# tensor(208.8255, device='cuda:0', grad_fn=<DivBackward0>)
# 19
# tensor(208.8013, device='cuda:0', grad_fn=<DivBackward0>)
# 20
# tensor(208.7673, device='cuda:0', grad_fn=<DivBackward0>)
# 21
# tensor(208.7560, device='cuda:0', grad_fn=<DivBackward0>)
# 22
# tensor(208.7603, device='cuda:0', grad_fn=<DivBackward0>)
# 23
# tensor(208.7446, device='cuda:0', grad_fn=<DivBackward0>)
# 24
# tensor(208.7584, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 25,loss = 207.8097
# 25
# tensor(208.7529, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 26,loss = 207.7748
# 26
# tensor(208.7309, device='cuda:0', grad_fn=<DivBackward0>)
# 27
# tensor(208.6884, device='cuda:0', grad_fn=<DivBackward0>)
# 28
# tensor(208.7163, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 29,loss = 207.7243
# 29
# tensor(208.7007, device='cuda:0', grad_fn=<DivBackward0>)
# 30
# tensor(208.6790, device='cuda:0', grad_fn=<DivBackward0>)
# 31
# tensor(208.6920, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 32,loss = 207.7112
# 32
# tensor(208.6618, device='cuda:0', grad_fn=<DivBackward0>)
# 33
# tensor(208.6624, device='cuda:0', grad_fn=<DivBackward0>)
# 34
# tensor(208.6303, device='cuda:0', grad_fn=<DivBackward0>)
# 35
# tensor(208.6509, device='cuda:0', grad_fn=<DivBackward0>)
# 36
# tensor(208.6420, device='cuda:0', grad_fn=<DivBackward0>)
# 37
# tensor(208.6438, device='cuda:0', grad_fn=<DivBackward0>)
# 38
# tensor(208.6125, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 39,loss = 207.6075
# 39
# tensor(208.6378, device='cuda:0', grad_fn=<DivBackward0>)
# 40
# tensor(208.5919, device='cuda:0', grad_fn=<DivBackward0>)
# 41
# tensor(208.6062, device='cuda:0', grad_fn=<DivBackward0>)
# 42
# tensor(208.5670, device='cuda:0', grad_fn=<DivBackward0>)
# 43
# tensor(208.5817, device='cuda:0', grad_fn=<DivBackward0>)
# 44
# tensor(208.5871, device='cuda:0', grad_fn=<DivBackward0>)
# 45
# tensor(208.5493, device='cuda:0', grad_fn=<DivBackward0>)
# 46
# tensor(208.5670, device='cuda:0', grad_fn=<DivBackward0>)
# 47
# tensor(208.5440, device='cuda:0', grad_fn=<DivBackward0>)
# 48
# tensor(208.5425, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 49,loss = 207.5714
# 49
# tensor(208.5443, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 50,loss = 207.5214
# 50
# tensor(208.5176, device='cuda:0', grad_fn=<DivBackward0>)
# 51
# tensor(208.5051, device='cuda:0', grad_fn=<DivBackward0>)
# 52
# tensor(208.4912, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 53,loss = 207.5214
# 53
# tensor(208.4560, device='cuda:0', grad_fn=<DivBackward0>)
# 54
# tensor(208.4643, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 55,loss = 207.4693
# 55
# tensor(208.4443, device='cuda:0', grad_fn=<DivBackward0>)
# 56
# tensor(208.4420, device='cuda:0', grad_fn=<DivBackward0>)
# 57
# tensor(208.4427, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 58,loss = 207.4424
# 58
# tensor(208.4161, device='cuda:0', grad_fn=<DivBackward0>)
# 59
# tensor(208.3865, device='cuda:0', grad_fn=<DivBackward0>)
# 60
# tensor(208.3892, device='cuda:0', grad_fn=<DivBackward0>)
# 61
# tensor(208.3793, device='cuda:0', grad_fn=<DivBackward0>)
# 62
# tensor(208.3905, device='cuda:0', grad_fn=<DivBackward0>)
# 63
# tensor(208.3538, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 64,loss = 207.4208
# 64
# tensor(208.3624, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 65,loss = 207.3144
# 65
# tensor(208.3378, device='cuda:0', grad_fn=<DivBackward0>)
# 66
# tensor(208.3184, device='cuda:0', grad_fn=<DivBackward0>)
# 67
# tensor(208.3079, device='cuda:0', grad_fn=<DivBackward0>)
# 68
# tensor(208.2724, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 69,loss = 207.2840
# 69
# tensor(208.2610, device='cuda:0', grad_fn=<DivBackward0>)
# 70
# tensor(208.2696, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 71,loss = 207.2356
# 71
# tensor(208.2604, device='cuda:0', grad_fn=<DivBackward0>)
# 72
# tensor(208.2275, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 73,loss = 207.1738
# 73
# tensor(208.1966, device='cuda:0', grad_fn=<DivBackward0>)
# 74
# tensor(208.1905, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 75,loss = 207.1373
# 75
# tensor(208.1594, device='cuda:0', grad_fn=<DivBackward0>)
# 76
# tensor(208.1506, device='cuda:0', grad_fn=<DivBackward0>)
# 77
# tensor(208.1099, device='cuda:0', grad_fn=<DivBackward0>)
# 78
# tensor(208.0908, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 79,loss = 207.1293
# 79
# tensor(208.0791, device='cuda:0', grad_fn=<DivBackward0>)
# 80
# tensor(208.0471, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 81,loss = 207.1276
# 81
# tensor(208.0307, device='cuda:0', grad_fn=<DivBackward0>)
# 82
# tensor(208.0012, device='cuda:0', grad_fn=<DivBackward0>)
# 83
# tensor(207.9579, device='cuda:0', grad_fn=<DivBackward0>)
# 84
# tensor(207.9356, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 85,loss = 206.9904
# 85
# tensor(207.9191, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 86,loss = 206.7439
# 86
# tensor(207.8650, device='cuda:0', grad_fn=<DivBackward0>)
# 87
# tensor(207.8646, device='cuda:0', grad_fn=<DivBackward0>)
# 88
# tensor(207.8612, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 89,loss = 206.7211
# 89
# tensor(207.8111, device='cuda:0', grad_fn=<DivBackward0>)
# 90
# tensor(207.7591, device='cuda:0', grad_fn=<DivBackward0>)
# Saving model (epoch = 91,loss = 206.6411
# 91
# tensor(207.6783, device='cuda:0', grad_fn=<DivBackward0>)
# 92
# tensor(207.6743, device='cuda:0', grad_fn=<DivBackward0>)
# 93
# tensor(207.6082, device='cuda:0', grad_fn=<DivBackward0>)
# 94
# tensor(207.5614, device='cuda:0', grad_fn=<DivBackward0>)
# 95
# tensor(207.5557, device='cuda:0', grad_fn=<DivBackward0>)
# 96
# tensor(207.5291, device='cuda:0', grad_fn=<DivBackward0>)
# 97
# tensor(207.4923, device='cuda:0', grad_fn=<DivBackward0>)
# 98
# tensor(207.4072, device='cuda:0', grad_fn=<DivBackward0>)
# 99
# tensor(207.3983, device='cuda:0', grad_fn=<DivBackward0>)
# Finished training after 100 epochs
# total params =  37121
# 206.64111558271375
# [221.2049560546875, 210.03379821777344, 209.7169647216797, 209.49700927734375, 209.34628295898438, 209.19964599609375, 209.13478088378906, 209.06240844726562, 209.02914428710938, 208.99208068847656, 208.9375762939453, 208.90664672851562, 208.8846893310547, 208.8677215576172, 208.85147094726562, 208.8401336669922, 208.8429718017578, 208.80560302734375, 208.8255157470703, 208.80126953125, 208.7672882080078, 208.75599670410156, 208.76028442382812, 208.7445831298828, 208.75843811035156, 208.75291442871094, 208.73089599609375, 208.68844604492188, 208.71630859375, 208.70066833496094, 208.67901611328125, 208.69200134277344, 208.66180419921875, 208.66244506835938, 208.63027954101562, 208.65087890625, 208.6420440673828, 208.64382934570312, 208.6125030517578, 208.63775634765625, 208.59190368652344, 208.60623168945312, 208.56695556640625, 208.5817108154297, 208.58712768554688, 208.54931640625, 208.5669708251953, 208.54396057128906, 208.54251098632812, 208.54429626464844, 208.51756286621094, 208.50506591796875, 208.49122619628906, 208.45603942871094, 208.46434020996094, 208.44427490234375, 208.44203186035156, 208.4426727294922, 208.41612243652344, 208.38653564453125, 208.3892364501953, 208.37928771972656, 208.3905029296875, 208.35379028320312, 208.36236572265625, 208.3377685546875, 208.318359375, 208.30792236328125, 208.27236938476562, 208.2610321044922, 208.26962280273438, 208.2604217529297, 208.2275390625, 208.19656372070312, 208.19052124023438, 208.1593780517578, 208.15057373046875, 208.1099090576172, 208.09083557128906, 208.07911682128906, 208.04705810546875, 208.03065490722656, 208.00120544433594, 207.95794677734375, 207.9355926513672, 207.91905212402344, 207.864990234375, 207.86460876464844, 207.86117553710938, 207.8110809326172, 207.7590789794922, 207.6782989501953, 207.6742706298828, 207.60821533203125, 207.56141662597656, 207.5557098388672, 207.52908325195312, 207.49234008789062, 207.4072265625, 207.39833068847656]
# 100
# Finished testing predictions!
# [[27.05108 ]
#  [28.276926]
#  [21.788933]
#  ...
#  [25.402418]
#  [25.398766]
#  [25.284672]]
# 207.39994833550372
# Saving results to BatchDiversity_1DCNN_01_1589Preds10.csv
# ALL Done!
